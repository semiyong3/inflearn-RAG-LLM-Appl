# %% [markdown]
# # 1. 패키지 설치

# %%
#%pip install -q python-dotenv langchain-community
# %pip install langchain-ollama
# Out:
# Requirement already satisfied: langchain-ollama in c:\program files\python\python311\lib\site-packages (0.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in c:\program files\python\python311\lib\site-packages (from langchain-ollama) (0.3.40)
# Requirement already satisfied: ollama<1,>=0.4.4 in c:\program files\python\python311\lib\site-packages (from langchain-ollama) (0.4.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\program files\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (0.3.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\program files\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\program files\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\program files\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\dksystems\appdata\roaming\python\python311\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dksystems\appdata\roaming\python\python311\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\program files\python\python311\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain-ollama) (2.10.6)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\program files\python\python311\lib\site-packages (from ollama<1,>=0.4.4->langchain-ollama) (0.28.1)
# Requirement already satisfied: anyio in c:\program files\python\python311\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (4.8.0)
# Requirement already satisfied: certifi in c:\program files\python\python311\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\program files\python\python311\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.0.7)
# Requirement already satisfied: idna in c:\program files\python\python311\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\program files\python\python311\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\program files\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\program files\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\program files\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\program files\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\program files\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\program files\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain-ollama) (2.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\program files\python\python311\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.3.1)

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
#from langchain_community.chat_models import ChatOllama
from langchain_ollama import ChatOllama
llm = ChatOllama(model="gemma2")

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File c:\Program Files\Python\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_ollama\chat_models.py:701, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     694 def _generate(
#     695     self,
#     696     messages: List[BaseMessage],
#    (...)
#     699     **kwargs: Any,
#     700 ) -> ChatResult:
# --> 701     final_chunk = self._chat_stream_with_aggregation(
#     702         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     703     )
#     704     generation_info = final_chunk.generation_info
#     705     chat_generation = ChatGeneration(
#     706         message=AIMessage(
#     707             content=final_chunk.text,
#    (...)
#     711         generation_info=generation_info,
#     712     )
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_ollama\chat_models.py:602, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     593 def _chat_stream_with_aggregation(
#     594     self,
#     595     messages: List[BaseMessage],
#    (...)
#     599     **kwargs: Any,
#     600 ) -> ChatGenerationChunk:
#     601     final_chunk = None
# --> 602     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     603         if not isinstance(stream_resp, str):
#     604             chunk = ChatGenerationChunk(
#     605                 message=AIMessageChunk(
#     606                     content=(
#    (...)
#     619                 ),
#     620             )
#
# File c:\Program Files\Python\Python311\Lib\site-packages\langchain_ollama\chat_models.py:589, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     586 chat_params = self._chat_params(messages, stop, **kwargs)
#     588 if chat_params["stream"]:
# --> 589     yield from self._client.chat(**chat_params)
#     590 else:
#     591     yield self._client.chat(**chat_params)
#
# File c:\Program Files\Python\Python311\Lib\site-packages\ollama\_client.py:163, in Client._request.<locals>.inner()
#     162 def inner():
# --> 163   with self._client.stream(*args, **kwargs) as r:
#     164     try:
#     165       r.raise_for_status()
#
# File c:\Program Files\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)
#     853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)
#     866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Program Files\Python\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File c:\Program Files\Python\Python311\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다

# %%
ai_message.content
# Out:
# '인프런에는 엄청나게 다양한 강의들이 있습니다!  어떤 분야에 관심이 있는지 알려주시면, 더 자세하고 도움이 되는 답변을 드릴 수 있어요. 😄\n\n예를 들어:\n\n* **IT & 개발:** 프로그래밍 (Python, Java, JavaScript 등), 웹개발, 데이터 분석, 클라우드 컴퓨팅\n* **디자인:** UI/UX 디자인, 그래픽 디자인, 일러스트레이션, 비주얼 효과\n* **비즈니스 & 마케팅:** 사업 계획, 디지털 마케팅, 콘텐츠 마케팅, 리더십\n* **취업 & 경력 개발:** 이력서 작성, 면접 준비, 네트워킹, 인턴십\n\n  ... 등등이 있습니다. \n\n혹시 특정 분야나 강의 이름을 알고 계신가요?  🔍'
